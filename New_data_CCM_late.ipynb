# %%
import pandas as pd
import matplotlib.pyplot as plt

# read the csv files and plot the data
df_AT = pd.read_csv(r"D:\VScode\van2015_repeat\data\AT.csv")
df_CO2 = pd.read_csv(r"D:\VScode\van2015_repeat\data\CO2.csv")
df_CH4 = pd.read_csv(r"D:\VScode\van2015_repeat\data\CH4.csv")
df_inso = pd.read_csv(r"D:\VScode\van2015_repeat\data\insolation.csv")

# crop the data and get the age>=0 and <=360000
age_start=360000
age_end=799000

df_AT = df_AT[(df_AT['age'] >= age_start) & (df_AT['age'] <= age_end)]
df_CO2 = df_CO2[(df_CO2['age'] >= age_start) & (df_CO2['age'] <= age_end)]
df_CH4 = df_CH4[(df_CH4['age'] >= age_start) & (df_CH4['age'] <= age_end)]
df_inso = df_inso[(df_inso['age'] >= age_start) & (df_inso['age'] <= age_end)]

fig, axs = plt.subplots(4, 1, figsize=(10, 15))

axs[0].plot(df_AT['age'], df_AT['AT'], color='r')
axs[0].set_title('AT')
axs[0].set_xlabel('age')
axs[0].set_ylabel('AT')

axs[1].plot(df_CO2['age'], df_CO2['CO2'], color='g')
axs[1].set_title('CO2')
axs[1].set_xlabel('age')
axs[1].set_ylabel('CO2')

axs[2].plot(df_CH4['age'], df_CH4['CH4'], color='b')
axs[2].set_title('CH4')
axs[2].set_xlabel('age')
axs[2].set_ylabel('CH4')

axs[3].plot(df_inso['age'], df_inso['inso'], color='k')
axs[3].set_title('insolation')
axs[3].set_xlabel('age')
axs[3].set_ylabel('insolation')

plt.tight_layout()
plt.show()

# print the length of the data
print(len(df_AT['age']))
# Out:
# 439

# %%
df_AT
# Out:
#         age        AT
# 360  360000 -8.325470
# 361  361000 -8.755994
# 362  362000 -8.841941
# 363  363000 -7.926593
# 364  364000 -7.907815
# ..      ...       ...
# 794  794000  0.665730
# 795  795000  0.655798
# 796  796000 -0.014437
# 797  797000  0.358238
# 798  798000 -0.551982
#
# [439 rows x 2 columns]

# %% [markdown]
# # AT and CO2

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_AT,
    df_pre     = df_CO2,
    E          = 4,
    tau        = -2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_AT,
    df_pre     = df_CO2,
    E         = 4,
    tau       = -2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# False

# %% [markdown]
# # AT and CH4

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_AT,
    df_pre     = df_CH4,
    E          = 4,
    tau        = -2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_AT,
    df_pre     = df_CH4,
    E         = 4,
    tau       = -2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# False

# %% [markdown]
# # Antarctic Temperature and insolation

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_AT,
    df_pre     = df_inso,
    E          = 4,
    tau        = -2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_AT,
    df_pre     = df_inso,
    E         = 4,
    tau       = -2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# True

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


Tps_list, forward_rhos, reverse_rhos = cf.find_optimal_Tp(
    df_sd      = df_AT,
    df_pre     = df_inso,
    E          = 4,
    tau        = -2,
    libSizes   = "100 200 300 400 500 600",
    sample     = 20,
    Tps        = range(-10, 11),
    interactive=True   
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 6
#       2 import importlib
#       3 importlib.reload(cf)
# ----> 6 Tps_list, forward_rhos, reverse_rhos = cf.find_optimal_Tp(
#       7     df_sd      = df_AT,
#       8     df_pre     = df_inso,
#       9     E          = 4,
#      10     tau        = -2,
#      11     libSizes   = "100 200 300 400 500 600",
#      12     sample     = 20,
#      13     Tps        = range(-10, 11),
#      14     interactive=True
#      15 )
#
# File d:\VScode\van2015_repeat\toolbox\ccm_functions.py:267, in find_optimal_Tp(df_sd, df_pre, E, tau, libSizes, sample, Tps, interactive)
#     264 # Loop over each Tp, calling the ccm_DOXmapForcing function once.
#     265 for Tp in Tps:
#     266     # Call ccm_DOXmapForcing with showPlot=False
# --> 267     ccm_out = ccm_DOXmapForcing(
#     268         df_sd      = df_sd,
#     269         df_pre     = df_pre,
#     270         E          = E,
#     271         tau        = tau,
#     272         libSizes   = libSizes,
#     273         Tp         = Tp,
#     274         sample     = sample,
#     275         showPlot   = False
#     276     )
#     278     # Extract max cross mapping skill for X->Y and Y->X
#     279     forward_rho = ccm_out[forward_key].max()  # X->Y
#
# File d:\VScode\van2015_repeat\toolbox\ccm_functions.py:175, in ccm_DOXmapForcing(df_sd, df_pre, E, tau, libSizes, Tp, sample, random, showPlot)
#     172     plt.show()
#     174 # Perform the CCM call
# --> 175 ccm_out = CCM(
#     176     dataFrame   = df,
#     177     E           = E,
#     178     tau         = tau,
#     179     columns     = column_name,   # predictor
#     180     target      = target_name,   # target
#     181     libSizes    = libSizes,
#     182     sample      = sample,
#     183     random      = random,
#     184     replacement = False,
#     185     Tp          = Tp
#     186 )
#     188 # Optional: plot the cross mapping skill
#     189 if showPlot:
#     190     # Construct keys for the forward/reverse cross mapping
#
# File d:\Users\User\anaconda3\envs\pz_venv_causal\lib\site-packages\pyEDM\CoreEDM.py:406, in CCM(pathIn, dataFile, dataFrame, pathOut, predictFile, E, Tp, knn, tau, exclusionRadius, columns, target, libSizes, sample, random, replacement, seed, embedded, includeData, parameterList, verbose, showPlot, noTime)
#     403 columns = pyEDM.AuxFunc.ArgTo_cppEDM_String( columns )
#     405 # D is a Python dict from pybind11 < cppEDM CCM
# --> 406 D = pyBindEDM.CCM( pathIn,
#     407                    dataFile,
#     408                    DF,
#     409                    pathOut,
#     410                    predictFile,
#     411                    E,
#     412                    Tp,
#     413                    knn,
#     414                    tau,
#     415                    exclusionRadius,
#     416                    columns,
#     417                    target,
#     418                    libSizes,
#     419                    sample,
#     420                    random,
#     421                    replacement,
#     422                    seed,
#     423                    embedded,
#     424                    includeData,
#     425                    parameterList,
#     426                    verbose )
#     428 # D has { "LibMeans" : DF }
#     429 # and if includeData has : { PredictStats1 : DF, PredictStats2 : DF }
#     430 libMeans = DataFrame( D[ "LibMeans" ] ) # Convert to pandas DataFrame
#
# RuntimeError: CrossMap(): Maximum libSize 600 too large for Tp -10 E 4 tau -2.  Maximum 424

# %% [markdown]
# # CO2 and CH4

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_CH4,
    df_pre     = df_CO2,
    E          = 4,
    tau        = -2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_CH4,
    df_pre     = df_CO2,
    E         = 4,
    tau       = -2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# False

# %% [markdown]
# # CO2 and insolation

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_CO2,
    df_pre     = df_inso,
    E          = 4,
    tau        = -2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_CO2,
    df_pre     = df_inso,
    E         = 4,
    tau       = -2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# False

# %% [markdown]
# # CH4 and insolation

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_CH4,
    df_pre     = df_inso,
    E          = 4,
    tau        = -2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_CH4,
    df_pre     = df_inso,
    E         = 4,
    tau       = -2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# False
