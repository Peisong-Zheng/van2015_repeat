# %%
import pandas as pd
import matplotlib.pyplot as plt

# read the csv files and plot the data
df_AT = pd.read_csv(r"D:\VScode\van2015_repeat\VOSTOK_data\AT.csv")
df_CO2 = pd.read_csv(r"D:\VScode\van2015_repeat\VOSTOK_data\CO2.csv")
df_CH4 = pd.read_csv(r"D:\VScode\van2015_repeat\VOSTOK_data\CH4.csv")
df_inso = pd.read_csv(r"D:\VScode\van2015_repeat\VOSTOK_data\insolation.csv")

fig, axs = plt.subplots(4, 1, figsize=(10, 15))

axs[0].plot(df_AT['age'], df_AT['AT'], color='r')
axs[0].set_title('AT')
axs[0].set_xlabel('age')
axs[0].set_ylabel('AT')

axs[1].plot(df_CO2['age'], df_CO2['CO2'], color='g')
axs[1].set_title('CO2')
axs[1].set_xlabel('age')
axs[1].set_ylabel('CO2')

axs[2].plot(df_CH4['age'], df_CH4['CH4'], color='b')
axs[2].set_title('CH4')
axs[2].set_xlabel('age')
axs[2].set_ylabel('CH4')

axs[3].plot(df_inso['age'], df_inso['inso'], color='k')
axs[3].set_title('insolation')
axs[3].set_xlabel('age')
axs[3].set_ylabel('insolation')

plt.tight_layout()
plt.show()

# print the length of the data
print(len(df_AT['age']))
# Out:
# 399

# %%
df_AT
# Out:
#         age        AT
# 0         0 -1.677747
# 1      1000 -2.076076
# 2      2000 -2.384293
# 3      3000 -2.990189
# 4      4000 -4.210263
# ..      ...       ...
# 394  394000 -0.528750
# 395  395000 -0.550213
# 396  396000 -1.364348
# 397  397000 -0.059487
# 398  398000 -0.255625
#
# [399 rows x 2 columns]

# %% [markdown]
# # AT and CO2

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_AT,
    df_pre     = df_CO2,
    E          = 4,
    tau        = 2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_AT,
    df_pre     = df_CO2,
    E         = 4,
    tau       = 2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# False

# %%
df_AT_crop
# Out:
#         age        AT
# 199  199000 -2.838108
# 200  198000 -2.805946
# 201  197000 -2.323148
# 202  196000 -2.476000
# 203  195000 -3.040259
# ..      ...       ...
# 394    4000 -4.210263
# 395    3000 -2.990189
# 396    2000 -2.384293
# 397    1000 -2.076076
# 398       0 -1.677747
#
# [200 rows x 2 columns]

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)
 

Tps_list, forward_rhos, reverse_rhos = cf.find_optimal_Tp(
    df_sd      = df_AT,
    df_pre     = df_CO2,
    E          = 4,
    tau        = 2,
    libSizes   = "100",
    sample     = 100,
    Tps        = range(-10, 11),
    interactive=True   
)

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)
 

Tps_list, forward_rhos, reverse_rhos = cf.find_optimal_Tp(
    df_sd      = df_AT,
    df_pre     = df_CO2,
    E          = 3,
    tau        = 1,
    libSizes   = "120 160 200 240 280 320 360",
    sample     = 100,
    Tps        = range(-10, 11),
    interactive=True   
)

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)
 

Tps_list, forward_rhos, reverse_rhos = cf.find_optimal_Tp(
    df_sd      = df_AT,
    df_pre     = df_CO2,
    E          = 5,
    tau        = 2,
    libSizes   = "40 80 120 160 200 240 280 320 360",
    sample     = 10,
    Tps        = range(-10, 11),
    interactive=True   
)

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)

# crop the df_AT and df_CO2 and only get the last 200 data points
df_AT_crop=df_AT.copy()
df_CO2_crop=df_CO2.copy()

df_AT_crop=df_AT_crop.iloc[-200:]
df_CO2_crop=df_CO2_crop.iloc[-200:]

Tps_list, forward_rhos, reverse_rhos = cf.find_optimal_Tp(
    df_sd      = df_AT_crop,
    df_pre     = df_CO2_crop,
    E          = 4,
    tau        = 2,
    libSizes   = "100",
    sample     = 100,
    Tps        = range(-10, 11),
    interactive=True   
)

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)
 

Tps_list, forward_rhos, reverse_rhos = cf.find_optimal_Tp(
    df_sd      = df_AT,
    df_pre     = df_CO2,
    E          = 4,
    tau        = 2,
    libSizes   = "40 80 120 160 200 240 280 320 360",
    sample     = 10,
    Tps        = range(-10, 11),
    interactive=True   
)

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


Tps_list, forward_rhos, reverse_rhos = cf.find_optimal_Tp(
    df_sd      = df_AT,
    df_pre     = df_CO2,
    E          = 4,
    tau        = 3,
    libSizes   = "80 120 160 200 240 280 320 360",
    sample     = 80,
    Tps        = range(-10, 11),
    interactive=True   
)

# %% [markdown]
# # AT and CH4

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_AT,
    df_pre     = df_CH4,
    E          = 4,
    tau        = 2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_AT,
    df_pre     = df_CH4,
    E         = 4,
    tau       = 2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# False

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


Tps_list, forward_rhos, reverse_rhos = cf.find_optimal_Tp(
    df_sd      = df_AT,
    df_pre     = df_CH4,
    E          = 4,
    tau        = 1,
    libSizes   = "40 80 120 160 200 240 280 320 360",
    sample     = 20,
    Tps        = range(-10, 11),
    interactive=True   
)

# %% [markdown]
# # AT and insolation

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_AT,
    df_pre     = df_inso,
    E          = 4,
    tau        = 2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_AT,
    df_pre     = df_inso,
    E         = 4,
    tau       = 2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# False

# %% [markdown]
# # CO2 and CH4

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_CH4,
    df_pre     = df_CO2,
    E          = 4,
    tau        = 2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_CH4,
    df_pre     = df_CO2,
    E         = 4,
    tau       = 2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# False

# %% [markdown]
# # CO2 and insolation

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_CO2,
    df_pre     = df_inso,
    E          = 4,
    tau        = 2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_CO2,
    df_pre     = df_inso,
    E         = 4,
    tau       = 2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# False

# %% [markdown]
# # CH4 and insolation

# %%
from toolbox import ccm_functions as cf
import importlib
importlib.reload(cf)


result = cf.ccm_DOXmapForcing(
    df_sd      = df_CH4,
    df_pre     = df_inso,
    E          = 4,
    tau        = 2,
    libSizes   = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample     = 10,
    showPlot   = True
)

from toolbox import significant_test as st
import importlib
importlib.reload(st)

ccm_out, ran_ccm_list,test_result = st.ccm_significance_test(
    df_sd      = df_CH4,
    df_pre     = df_inso,
    E         = 4,
    tau       = 2,
    Tp =0,
    n_ran     = 100,
    libSizes  = "20 40 60 80 100 120 140 160 180 200 220 240 260 280 300 320 340 360",
    sample    = 10,
    showPlot  = True
)


print(test_result)
# Out:
# False
